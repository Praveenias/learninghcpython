# %%
#spiral_matrics
matrix = [[1,2,3],[4,5,6],[7,8,9]]

top = left = 0
bottom = len(matrix)-1
right = len(matrix[0])-1

ele = []
while left <=right and top <=bottom:
  for i in range(left,right+1):
    ele.append(matrix[top][i])
  top +=1

  for i in range(top,bottom+1):
    ele.append(matrix[i][right])
  right -=1


  if top <= bottom:
    for i in range(right,left-1,-1):
      ele.append(matrix[bottom][i])
      bottom -=1

  if right >=left:
    for i in range(bottom,top-1,-1):
      ele.append(matrix[i][left])
      left +=1



 # break
  
# ele = []
# for i in range(len(matrix)):
#   ele.append(matrix[temp1][i])
print(ele)
# Out:
# [1, 2, 3, 6, 9, 8, 4]

# %%
#set0
matrix = [[1,1,1],[1,0,1],[1,1,1]]

n = len(matrix)-1
m = len(matrix[0])-1
row = [False for _ in range(n)]
col = [False for _ in range(m)]
print(row,col)
for i in range(n):
  for j in range(m):
      if matrix[i][j] == 0:
          row[i] = True
          col[j] = True
# Out:
# [False, False] [False, False]
