# %%
import pandas as pd

# %%
df = pd.read_csv('employee_attriction.csv')
data = pd.get_dummies(df, columns=['Job Role', 'Overtime', 'Department'], drop_first=True)
print(data)
# Out:
#    Age  Salary  Years at Company  Job Satisfaction  Work-Life Balance  \
# 0   29   70000                 3                 4                  3
# 1   35   90000                 7                 3                  4
# 2   24   60000                 1                 5                  2
# 3   40  120000                10                 2                  4
# 4   32   80000                 4                 4                  3
# 5   28   50000                 2                 5                  3
# 6   37   95000                 8                 3                  4
# 7   30   85000                 5                 4                  3
# 8   45  110000                12                 2                  4
# 9   26   55000                 1                 5                  2
#
#    Training Hours  Attrition  Job Role_Manager  Job Role_Software Eng  \
# 0              20          1             False                   True
# ...
