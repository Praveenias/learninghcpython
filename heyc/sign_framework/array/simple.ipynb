# %%
def kidsWithCandies(candies,extraCandies):
        l1 = []
        max_candi = max(candies)
        for i in candies:
            l1.append(i+extraCandies >= max_candi)
        return l1
print(kidsWithCandies([2,3,5,1,3],3))
# Out:
# [True, True, True, False, True]

# %%
def pivotIndex(nums) -> int:
        for i in range(len(nums)):
            print(sum(nums[:i]),sum(nums[i+1:]),nums[i+1:])
            if sum(nums[:i]) == sum(nums[i+1:]):
                return i
        return -1

print(pivotIndex([-1,-1,0,1,1,0]))
# Out:
# 0 1 [-1, 0, 1, 1, 0]
# -1 2 [0, 1, 1, 0]
# -2 2 [1, 1, 0]
# -2 1 [1, 0]
# -1 0 [0]
# 0 0 []
# 5

# %%
a=2
b=10
while b:
  a,b = b, a%b
print(a)
# Out:
# 2
